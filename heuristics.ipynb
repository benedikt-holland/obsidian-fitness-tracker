# %%
import pandas as pd

# %%
hist = pd.read_csv("history.csv")
hist.head()
# Out:
#         check         name  variant  value  maximum unit category subcategory  \
# 0  2024-06-27  Back raises    plate   15.0      NaN   kg     back       lower
# 1  2024-06-27       Squads     free   60.0      NaN   kg     legs        full
# 2  2024-06-27    Leg press  machine  160.0      NaN   kg     legs        full
# 3  2024-06-27   Quadriceps  machine   65.0      NaN   kg     legs  quadriceps
# 4  2024-06-27   Hamstrings  machine   55.0      NaN   kg     legs  hamstrings
#
#   note
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
hist.groupby("category").count()["check"]
# Out:
# category
# arms         2
# back         7
# chest        4
# legs         5
# shoulders    3
# Name: check, dtype: int64

# %%
INPUT = '../../obsidian/living/fitness/Gym.md' 
with open(INPUT, 'r') as f:
    lines = f.readlines()
data = [] 
for line in lines:
    if line[0] != "|":
        continue  
    # Data is kept in a markdown table
    data.append([l.strip() for l in line[1:-2].split("|")])
header = data[0]
data = data[2:]  
df = pd.DataFrame(data, columns=header)

# %%
orig_cols = df.columns
df.head()
# Out:
#   check          name  variant value maximum unit category subcategory  \
# 0        Lat pulldown     wide    55           kg     back       outer
# 1        Lat pulldown    close    55           kg     back       outer
# 2              Rowing     pole    40           kg     back       upper
# 3              Rowing  machine    50           kg     back       upper
# 4         Reverse fly  machine    35           kg     back       inner
#
#       note
# 0  machine
# 1  machine
# 2
# 3
# 4

# %%
df["full_name"] = df.name + " " + df.variant
hist["full_name"] = hist.name + " " + hist.variant

# %%
hist.check = pd.to_datetime(hist.check)
hist["day_diff"] = hist.check.rsub(pd.Timestamp.now()).dt.days

# %%
cols = ["category", "subcategory", "full_name"]

# %%
group_cols = [] 
for col in cols: 
    group_cols.append(col)
    df = df.join(hist.groupby(group_cols).count().check.rename(col) , on=group_cols, rsuffix="_count")
    df[col+"_count"] = df[col+"_count"].fillna(0)

# %%
df = df.join(hist.groupby(group_cols).min().day_diff.rename("days") , on=group_cols)

# %%
df
# Out:
#    check            name   variant value maximum unit   category subcategory  \
# 0           Lat pulldown      wide    55           kg       back       outer
# 1           Lat pulldown     close    55           kg       back       outer
# 2                 Rowing      pole    40           kg       back       upper
# 3                 Rowing   machine    50           kg       back       upper
# 4            Reverse fly   machine    35           kg       back       inner
# 5             Single row   machine    35           kg       back       inner
# 6            Back raises     plate    15           kg       back       lower
# 7            Back raises      pole    70           kg       back       lower
# 8                  Curls  dumbells    16           kg       arms      bizeps
# 9                  Curls    hammer    16           kg       arms      bizeps
# 10                 Curls      pole   7.5           kg       arms      bizeps
# 11                 Curls   machine    30           kg       arms      bizeps
# 12                 Curls     cable    30           kg       arms      bizeps
# 13                 Curls     cable    30           kg       arms      bizeps
# 14         Triceps press     cable    45           kg       arms     triceps
# 15         Triceps press     cable    45           kg       arms     triceps
# 16         Triceps press  overhead    45           kg       arms     triceps
# 17             Treadmill   running    30          min     cardio      cardio
# 18           Bench press  vertical    60           kg      chest     central
# 19           Bench press   incline    18                   chest       upper
# 20           Bench press   incline                         chest       upper
# 21           Bench press   incline                         chest       upper
# 22        Military press      pole    40           kg  shoulders       upper
# 23        Military press  dumbells    16           kg  shoulders       upper
# 24                  Dips   machine    20           kg      chest       lower
# 25           Bench press  negative    30           kg      chest       lower
# 26                   Fly   machine    55           kg      chest       inner
# 27                   Fly  dumbells    12           kg      chest       inner
# 28          Side lifting     cable  12.5           kg  shoulders        side
# 29         Front lifting     cable    10           kg  shoulders       front
# 30                Squads      free    60           kg       legs        full
# 31             Leg press   machine   160           kg       legs        full
# 32            Quadriceps   machine    65           kg       legs  quadriceps
# 33            Hamstrings   machine    55           kg       legs  hamstrings
# 34                Calves  standing   100           kg       legs      calves
# 35            Abdominals      free    15                    legs  abdominals
# 36               Shruggs  dumbells    30           kg  shoulders        neck
# 37           Bench press   pushups    15                   chest     central
#
#         note                full_name  category_count  subcategory_count  \
# 0    machine        Lat pulldown wide             7.0                2.0
# 1    machine       Lat pulldown close             7.0                2.0
# 2                         Rowing pole             7.0                2.0
# 3                      Rowing machine             7.0                2.0
# 4                 Reverse fly machine             7.0                2.0
# 5                  Single row machine             7.0                2.0
# 6                   Back raises plate             7.0                1.0
# 7                    Back raises pole             7.0                1.0
# 8                      Curls dumbells             2.0                0.0
# 9   dumbells             Curls hammer             2.0                0.0
# 10  preacher               Curls pole             2.0                0.0
# 11  preacher            Curls machine             2.0                0.0
# 12  preacher              Curls cable             2.0                0.0
# 13    normal              Curls cable             2.0                0.0
# 14      rope      Triceps press cable             2.0                2.0
# 15      pole      Triceps press cable             2.0                2.0
# 16             Triceps press overhead             2.0                2.0
# 17   machine        Treadmill running             0.0                0.0
# 18               Bench press vertical             4.0                1.0
# 19  dumbells      Bench press incline             4.0                1.0
# 20      pole      Bench press incline             4.0                1.0
# 21   machine      Bench press incline             4.0                1.0
# 22                Military press pole             3.0                1.0
# 23            Military press dumbells             3.0                1.0
# 24                       Dips machine             4.0                1.0
# 25   machine     Bench press negative             4.0                1.0
# 26                        Fly machine             4.0                1.0
# 27                       Fly dumbells             4.0                1.0
# 28                 Side lifting cable             3.0                1.0
# 29                Front lifting cable             3.0                1.0
# 30                        Squads free             5.0                2.0
# 31                  Leg press machine             5.0                2.0
# 32                 Quadriceps machine             5.0                1.0
# 33                 Hamstrings machine             5.0                1.0
# 34                    Calves standing             5.0                1.0
# 35                    Abdominals free             5.0                0.0
# 36                   Shruggs dumbells             3.0                0.0
# 37                Bench press pushups             4.0                1.0
#
#     full_name_count  days
# 0               1.0  30.0
# 1               1.0  30.0
# 2               1.0  30.0
# 3               1.0  30.0
# 4               1.0  30.0
# 5               1.0  30.0
# 6               1.0  31.0
# 7               0.0   NaN
# 8               0.0   NaN
# 9               0.0   NaN
# 10              0.0   NaN
# 11              0.0   NaN
# 12              0.0   NaN
# 13              0.0   NaN
# 14              1.0  19.0
# 15              1.0  19.0
# 16              1.0  19.0
# 17              0.0   NaN
# 18              1.0  19.0
# 19              1.0  19.0
# 20              1.0  19.0
# 21              1.0  19.0
# 22              1.0  19.0
# 23              0.0   NaN
# 24              1.0  19.0
# 25              0.0   NaN
# 26              1.0  19.0
# 27              0.0   NaN
# 28              1.0  19.0
# 29              1.0  19.0
# 30              1.0  31.0
# 31              1.0  31.0
# 32              1.0  31.0
# 33              1.0  31.0
# 34              1.0  31.0
# 35              0.0   NaN
# 36              0.0   NaN
# 37              0.0   NaN

# %%
total = hist.shape[0] 
for col in [c+"_count" for c in cols]:
    df[col.split("_")[0]+"%"] = (df[col] / total).fillna(0)
    total = df[col]

# %%
df
# Out:
#    check            name   variant value maximum unit   category subcategory  \
# 0           Lat pulldown      wide    55           kg       back       outer
# 1           Lat pulldown     close    55           kg       back       outer
# 2                 Rowing      pole    40           kg       back       upper
# 3                 Rowing   machine    50           kg       back       upper
# 4            Reverse fly   machine    35           kg       back       inner
# 5             Single row   machine    35           kg       back       inner
# 6            Back raises     plate    15           kg       back       lower
# 7            Back raises      pole    70           kg       back       lower
# 8                  Curls  dumbells    16           kg       arms      bizeps
# 9                  Curls    hammer    16           kg       arms      bizeps
# 10                 Curls      pole   7.5           kg       arms      bizeps
# 11                 Curls   machine    30           kg       arms      bizeps
# 12                 Curls     cable    30           kg       arms      bizeps
# 13                 Curls     cable    30           kg       arms      bizeps
# 14         Triceps press     cable    45           kg       arms     triceps
# 15         Triceps press     cable    45           kg       arms     triceps
# 16         Triceps press  overhead    45           kg       arms     triceps
# 17             Treadmill   running    30          min     cardio      cardio
# 18           Bench press  vertical    60           kg      chest     central
# 19           Bench press   incline    18                   chest       upper
# 20           Bench press   incline                         chest       upper
# 21           Bench press   incline                         chest       upper
# 22        Military press      pole    40           kg  shoulders       upper
# 23        Military press  dumbells    16           kg  shoulders       upper
# 24                  Dips   machine    20           kg      chest       lower
# 25           Bench press  negative    30           kg      chest       lower
# 26                   Fly   machine    55           kg      chest       inner
# 27                   Fly  dumbells    12           kg      chest       inner
# 28          Side lifting     cable  12.5           kg  shoulders        side
# 29         Front lifting     cable    10           kg  shoulders       front
# 30                Squads      free    60           kg       legs        full
# 31             Leg press   machine   160           kg       legs        full
# 32            Quadriceps   machine    65           kg       legs  quadriceps
# 33            Hamstrings   machine    55           kg       legs  hamstrings
# 34                Calves  standing   100           kg       legs      calves
# 35            Abdominals      free    15                    legs  abdominals
# 36               Shruggs  dumbells    30           kg  shoulders        neck
# 37           Bench press   pushups    15                   chest     central
#
#         note                full_name  category_count  subcategory_count  \
# 0    machine        Lat pulldown wide             7.0                2.0
# 1    machine       Lat pulldown close             7.0                2.0
# 2                         Rowing pole             7.0                2.0
# 3                      Rowing machine             7.0                2.0
# 4                 Reverse fly machine             7.0                2.0
# 5                  Single row machine             7.0                2.0
# 6                   Back raises plate             7.0                1.0
# 7                    Back raises pole             7.0                1.0
# 8                      Curls dumbells             2.0                0.0
# 9   dumbells             Curls hammer             2.0                0.0
# 10  preacher               Curls pole             2.0                0.0
# 11  preacher            Curls machine             2.0                0.0
# 12  preacher              Curls cable             2.0                0.0
# 13    normal              Curls cable             2.0                0.0
# 14      rope      Triceps press cable             2.0                2.0
# 15      pole      Triceps press cable             2.0                2.0
# 16             Triceps press overhead             2.0                2.0
# 17   machine        Treadmill running             0.0                0.0
# 18               Bench press vertical             4.0                1.0
# 19  dumbells      Bench press incline             4.0                1.0
# 20      pole      Bench press incline             4.0                1.0
# 21   machine      Bench press incline             4.0                1.0
# 22                Military press pole             3.0                1.0
# 23            Military press dumbells             3.0                1.0
# 24                       Dips machine             4.0                1.0
# 25   machine     Bench press negative             4.0                1.0
# 26                        Fly machine             4.0                1.0
# 27                       Fly dumbells             4.0                1.0
# 28                 Side lifting cable             3.0                1.0
# 29                Front lifting cable             3.0                1.0
# 30                        Squads free             5.0                2.0
# 31                  Leg press machine             5.0                2.0
# 32                 Quadriceps machine             5.0                1.0
# 33                 Hamstrings machine             5.0                1.0
# 34                    Calves standing             5.0                1.0
# 35                    Abdominals free             5.0                0.0
# 36                   Shruggs dumbells             3.0                0.0
# 37                Bench press pushups             4.0                1.0
#
#     full_name_count  days  category_count%  subcategory_count%  \
# 0               1.0  30.0         0.333333            0.285714
# 1               1.0  30.0         0.333333            0.285714
# 2               1.0  30.0         0.333333            0.285714
# 3               1.0  30.0         0.333333            0.285714
# 4               1.0  30.0         0.333333            0.285714
# 5               1.0  30.0         0.333333            0.285714
# 6               1.0  31.0         0.333333            0.142857
# 7               0.0   NaN         0.333333            0.142857
# 8               0.0   NaN         0.095238            0.000000
# 9               0.0   NaN         0.095238            0.000000
# 10              0.0   NaN         0.095238            0.000000
# 11              0.0   NaN         0.095238            0.000000
# 12              0.0   NaN         0.095238            0.000000
# 13              0.0   NaN         0.095238            0.000000
# 14              1.0  19.0         0.095238            1.000000
# 15              1.0  19.0         0.095238            1.000000
# 16              1.0  19.0         0.095238            1.000000
# 17              0.0   NaN         0.000000            0.000000
# 18              1.0  19.0         0.190476            0.250000
# 19              1.0  19.0         0.190476            0.250000
# 20              1.0  19.0         0.190476            0.250000
# 21              1.0  19.0         0.190476            0.250000
# 22              1.0  19.0         0.142857            0.333333
# 23              0.0   NaN         0.142857            0.333333
# 24              1.0  19.0         0.190476            0.250000
# 25              0.0   NaN         0.190476            0.250000
# 26              1.0  19.0         0.190476            0.250000
# 27              0.0   NaN         0.190476            0.250000
# 28              1.0  19.0         0.142857            0.333333
# 29              1.0  19.0         0.142857            0.333333
# 30              1.0  31.0         0.238095            0.400000
# 31              1.0  31.0         0.238095            0.400000
# 32              1.0  31.0         0.238095            0.200000
# 33              1.0  31.0         0.238095            0.200000
# 34              1.0  31.0         0.238095            0.200000
# 35              0.0   NaN         0.238095            0.000000
# 36              0.0   NaN         0.142857            0.000000
# 37              0.0   NaN         0.190476            0.250000
#
#     full_name_count%
# 0                0.5
# 1                0.5
# 2                0.5
# 3                0.5
# 4                0.5
# 5                0.5
# 6                1.0
# 7                0.0
# 8                0.0
# 9                0.0
# 10               0.0
# 11               0.0
# 12               0.0
# 13               0.0
# 14               0.5
# 15               0.5
# 16               0.5
# 17               0.0
# 18               1.0
# 19               1.0
# 20               1.0
# 21               1.0
# 22               1.0
# 23               0.0
# 24               1.0
# 25               0.0
# 26               1.0
# 27               0.0
# 28               1.0
# 29               1.0
# 30               0.5
# 31               0.5
# 32               1.0
# 33               1.0
# 34               1.0
# 35               0.0
# 36               0.0
# 37               0.0

# %%
INPUT = '../../obsidian/living/fitness/Gym goals.md' 
with open(INPUT, 'r') as f:
    lines = f.readlines()
data = [] 
for line in lines:
    if line[0] != "|":
        continue  
    # Data is kept in a markdown table
    data.append([l.strip() for l in line[1:-2].split("|")])
header = data[0]
data = data[2:]  
goals = pd.DataFrame(data, columns=header)
goals
# Out:
#      category subcategory goal
# 0        back       upper    1
# 1        back       outer    2
# 2        back       lower    1
# 3        back       inner    2
# 4        arms      bizeps    3
# 5        arms     triceps    2
# 6      cardio      cardio    1
# 7       chest     central    1
# 8       chest       upper    1
# 9       chest       lower    1
# 10  shoulders       upper    1
# 11  shoulders        side    1
# 12  shoulders       front    1
# 13      chest       inner    1
# 14       legs        full    2
# 15       legs  quadriceps    1
# 16       legs  hamstrings    1
# 17       legs      calves    1
# 18       legs  abdominals    1

# %%
goals.goal = goals.goal.astype(int)

# %%
total = goals.goal.sum()
group_cols = [] 
for col in ["category", "subcategory"]:
    group_cols.append(col)
    goals = goals.join(goals.groupby(group_cols).sum()["goal"].rename(col), on=group_cols, rsuffix="_total")
    goals[col+"%"] = goals[col+"_total"] / total
    total = goals[col+"_total"]

# %%
goals
# Out:
#      category subcategory  goal  category_total  category%  subcategory_total  \
# 0        back       upper     1               6       0.24                  1
# 1        back       outer     2               6       0.24                  2
# 2        back       lower     1               6       0.24                  1
# 3        back       inner     2               6       0.24                  2
# 4        arms      bizeps     3               5       0.20                  3
# 5        arms     triceps     2               5       0.20                  2
# 6      cardio      cardio     1               1       0.04                  1
# 7       chest     central     1               4       0.16                  1
# 8       chest       upper     1               4       0.16                  1
# 9       chest       lower     1               4       0.16                  1
# 10  shoulders       upper     1               3       0.12                  1
# 11  shoulders        side     1               3       0.12                  1
# 12  shoulders       front     1               3       0.12                  1
# 13      chest       inner     1               4       0.16                  1
# 14       legs        full     2               6       0.24                  2
# 15       legs  quadriceps     1               6       0.24                  1
# 16       legs  hamstrings     1               6       0.24                  1
# 17       legs      calves     1               6       0.24                  1
# 18       legs  abdominals     1               6       0.24                  1
#
#     subcategory%
# 0       0.166667
# 1       0.333333
# 2       0.166667
# 3       0.333333
# 4       0.600000
# 5       0.400000
# 6       1.000000
# 7       0.250000
# 8       0.250000
# 9       0.250000
# 10      0.333333
# 11      0.333333
# 12      0.333333
# 13      0.250000
# 14      0.333333
# 15      0.166667
# 16      0.166667
# 17      0.166667
# 18      0.166667

# %%
df = df.join(goals.set_index(["category", "subcategory"]), on=["category", "subcategory"], rsuffix="_goal", )
df.head()
# Out:
#   check          name  variant value maximum unit category subcategory  \
# 0        Lat pulldown     wide    55           kg     back       outer
# 1        Lat pulldown    close    55           kg     back       outer
# 2              Rowing     pole    40           kg     back       upper
# 3              Rowing  machine    50           kg     back       upper
# 4         Reverse fly  machine    35           kg     back       inner
#
#       note            full_name  ...  full_name_count  days  category_count%  \
# 0  machine    Lat pulldown wide  ...              1.0  30.0         0.333333
# 1  machine   Lat pulldown close  ...              1.0  30.0         0.333333
# 2                   Rowing pole  ...              1.0  30.0         0.333333
# 3                Rowing machine  ...              1.0  30.0         0.333333
# 4           Reverse fly machine  ...              1.0  30.0         0.333333
#
#    subcategory_count%  full_name_count%  goal  category_total  category%  \
# 0            0.285714               0.5   2.0             6.0       0.24
# 1            0.285714               0.5   2.0             6.0       0.24
# 2            0.285714               0.5   1.0             6.0       0.24
# 3            0.285714               0.5   1.0             6.0       0.24
# 4            0.285714               0.5   2.0             6.0       0.24
#
#    subcategory_total  subcategory%
# 0                2.0      0.333333
# 1                2.0      0.333333
# 2                1.0      0.166667
# 3                1.0      0.166667
# 4                2.0      0.333333
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['check', 'name', 'variant', 'value', 'maximum', 'unit', 'category',
#        'subcategory', 'note', 'full_name', 'category_count',
#        'subcategory_count', 'full_name_count', 'days', 'category_count%',
#        'subcategory_count%', 'full_name_count%', 'goal', 'category_total',
#        'category%', 'subcategory_total', 'subcategory%'],
#       dtype='object')

# %%
goals.head()
# Out:
#   category subcategory  goal  category_total  category%  subcategory_total  \
# 0     back       upper     1               6       0.24                  1
# 1     back       outer     2               6       0.24                  2
# 2     back       lower     1               6       0.24                  1
# 3     back       inner     2               6       0.24                  2
# 4     arms      bizeps     3               5       0.20                  3
#
#    subcategory%
# 0      0.166667
# 1      0.333333
# 2      0.166667
# 3      0.333333
# 4      0.600000

# %%
df.groupby("name").count()["check"]
# Out:
# name
# Abdominals        1
# Back raises       2
# Bench press       6
# Calves            1
# Curls             6
# Dips              1
# Fly               2
# Front lifting     1
# Hamstrings        1
# Lat pulldown      2
# Leg press         1
# Military press    2
# Quadriceps        1
# Reverse fly       1
# Rowing            2
# Shruggs           1
# Side lifting      1
# Single row        1
# Squads            1
# Treadmill         1
# Triceps press     3
# Name: check, dtype: int64

# %%
for col in ["category", "subcategory"]:
    df[col+"_score"] = (df[col+"%"]  - df[col+"_count%"]) + 1
df["score"] = df.category_score + df.subcategory_score
df
# Out:
#    check            name   variant value maximum unit   category subcategory  \
# 0           Lat pulldown      wide    55           kg       back       outer
# 1           Lat pulldown     close    55           kg       back       outer
# 2                 Rowing      pole    40           kg       back       upper
# 3                 Rowing   machine    50           kg       back       upper
# 4            Reverse fly   machine    35           kg       back       inner
# 5             Single row   machine    35           kg       back       inner
# 6            Back raises     plate    15           kg       back       lower
# 7            Back raises      pole    70           kg       back       lower
# 8                  Curls  dumbells    16           kg       arms      bizeps
# 9                  Curls    hammer    16           kg       arms      bizeps
# 10                 Curls      pole   7.5           kg       arms      bizeps
# 11                 Curls   machine    30           kg       arms      bizeps
# 12                 Curls     cable    30           kg       arms      bizeps
# 13                 Curls     cable    30           kg       arms      bizeps
# 14         Triceps press     cable    45           kg       arms     triceps
# 15         Triceps press     cable    45           kg       arms     triceps
# 16         Triceps press  overhead    45           kg       arms     triceps
# 17             Treadmill   running    30          min     cardio      cardio
# 18           Bench press  vertical    60           kg      chest     central
# 19           Bench press   incline    18                   chest       upper
# 20           Bench press   incline                         chest       upper
# 21           Bench press   incline                         chest       upper
# 22        Military press      pole    40           kg  shoulders       upper
# 23        Military press  dumbells    16           kg  shoulders       upper
# 24                  Dips   machine    20           kg      chest       lower
# 25           Bench press  negative    30           kg      chest       lower
# 26                   Fly   machine    55           kg      chest       inner
# 27                   Fly  dumbells    12           kg      chest       inner
# 28          Side lifting     cable  12.5           kg  shoulders        side
# 29         Front lifting     cable    10           kg  shoulders       front
# 30                Squads      free    60           kg       legs        full
# 31             Leg press   machine   160           kg       legs        full
# 32            Quadriceps   machine    65           kg       legs  quadriceps
# 33            Hamstrings   machine    55           kg       legs  hamstrings
# 34                Calves  standing   100           kg       legs      calves
# 35            Abdominals      free    15                    legs  abdominals
# 36               Shruggs  dumbells    30           kg  shoulders        neck
# 37           Bench press   pushups    15                   chest     central
#
#         note                full_name  ...  subcategory_count%  \
# 0    machine        Lat pulldown wide  ...            0.285714
# 1    machine       Lat pulldown close  ...            0.285714
# 2                         Rowing pole  ...            0.285714
# 3                      Rowing machine  ...            0.285714
# 4                 Reverse fly machine  ...            0.285714
# 5                  Single row machine  ...            0.285714
# 6                   Back raises plate  ...            0.142857
# 7                    Back raises pole  ...            0.142857
# 8                      Curls dumbells  ...            0.000000
# 9   dumbells             Curls hammer  ...            0.000000
# 10  preacher               Curls pole  ...            0.000000
# 11  preacher            Curls machine  ...            0.000000
# 12  preacher              Curls cable  ...            0.000000
# 13    normal              Curls cable  ...            0.000000
# 14      rope      Triceps press cable  ...            1.000000
# 15      pole      Triceps press cable  ...            1.000000
# 16             Triceps press overhead  ...            1.000000
# 17   machine        Treadmill running  ...            0.000000
# 18               Bench press vertical  ...            0.250000
# 19  dumbells      Bench press incline  ...            0.250000
# 20      pole      Bench press incline  ...            0.250000
# 21   machine      Bench press incline  ...            0.250000
# 22                Military press pole  ...            0.333333
# 23            Military press dumbells  ...            0.333333
# 24                       Dips machine  ...            0.250000
# 25   machine     Bench press negative  ...            0.250000
# 26                        Fly machine  ...            0.250000
# 27                       Fly dumbells  ...            0.250000
# 28                 Side lifting cable  ...            0.333333
# 29                Front lifting cable  ...            0.333333
# 30                        Squads free  ...            0.400000
# 31                  Leg press machine  ...            0.400000
# 32                 Quadriceps machine  ...            0.200000
# 33                 Hamstrings machine  ...            0.200000
# 34                    Calves standing  ...            0.200000
# 35                    Abdominals free  ...            0.000000
# 36                   Shruggs dumbells  ...            0.000000
# 37                Bench press pushups  ...            0.250000
#
#     full_name_count%  goal  category_total  category%  subcategory_total  \
# 0                0.5   2.0             6.0       0.24                2.0
# 1                0.5   2.0             6.0       0.24                2.0
# 2                0.5   1.0             6.0       0.24                1.0
# 3                0.5   1.0             6.0       0.24                1.0
# 4                0.5   2.0             6.0       0.24                2.0
# 5                0.5   2.0             6.0       0.24                2.0
# 6                1.0   1.0             6.0       0.24                1.0
# 7                0.0   1.0             6.0       0.24                1.0
# 8                0.0   3.0             5.0       0.20                3.0
# 9                0.0   3.0             5.0       0.20                3.0
# 10               0.0   3.0             5.0       0.20                3.0
# 11               0.0   3.0             5.0       0.20                3.0
# 12               0.0   3.0             5.0       0.20                3.0
# 13               0.0   3.0             5.0       0.20                3.0
# 14               0.5   2.0             5.0       0.20                2.0
# 15               0.5   2.0             5.0       0.20                2.0
# 16               0.5   2.0             5.0       0.20                2.0
# 17               0.0   1.0             1.0       0.04                1.0
# 18               1.0   1.0             4.0       0.16                1.0
# 19               1.0   1.0             4.0       0.16                1.0
# 20               1.0   1.0             4.0       0.16                1.0
# 21               1.0   1.0             4.0       0.16                1.0
# 22               1.0   1.0             3.0       0.12                1.0
# 23               0.0   1.0             3.0       0.12                1.0
# 24               1.0   1.0             4.0       0.16                1.0
# 25               0.0   1.0             4.0       0.16                1.0
# 26               1.0   1.0             4.0       0.16                1.0
# 27               0.0   1.0             4.0       0.16                1.0
# 28               1.0   1.0             3.0       0.12                1.0
# 29               1.0   1.0             3.0       0.12                1.0
# 30               0.5   2.0             6.0       0.24                2.0
# 31               0.5   2.0             6.0       0.24                2.0
# 32               1.0   1.0             6.0       0.24                1.0
# 33               1.0   1.0             6.0       0.24                1.0
# 34               1.0   1.0             6.0       0.24                1.0
# 35               0.0   1.0             6.0       0.24                1.0
# 36               0.0   NaN             NaN        NaN                NaN
# 37               0.0   1.0             4.0       0.16                1.0
#
#     subcategory%  category_score  subcategory_score     score
# 0       0.333333        0.906667           1.047619  1.954286
# 1       0.333333        0.906667           1.047619  1.954286
# 2       0.166667        0.906667           0.880952  1.787619
# 3       0.166667        0.906667           0.880952  1.787619
# 4       0.333333        0.906667           1.047619  1.954286
# 5       0.333333        0.906667           1.047619  1.954286
# 6       0.166667        0.906667           1.023810  1.930476
# 7       0.166667        0.906667           1.023810  1.930476
# 8       0.600000        1.104762           1.600000  2.704762
# 9       0.600000        1.104762           1.600000  2.704762
# 10      0.600000        1.104762           1.600000  2.704762
# 11      0.600000        1.104762           1.600000  2.704762
# 12      0.600000        1.104762           1.600000  2.704762
# 13      0.600000        1.104762           1.600000  2.704762
# 14      0.400000        1.104762           0.400000  1.504762
# 15      0.400000        1.104762           0.400000  1.504762
# 16      0.400000        1.104762           0.400000  1.504762
# 17      1.000000        1.040000           2.000000  3.040000
# 18      0.250000        0.969524           1.000000  1.969524
# 19      0.250000        0.969524           1.000000  1.969524
# 20      0.250000        0.969524           1.000000  1.969524
# 21      0.250000        0.969524           1.000000  1.969524
# 22      0.333333        0.977143           1.000000  1.977143
# 23      0.333333        0.977143           1.000000  1.977143
# 24      0.250000        0.969524           1.000000  1.969524
# 25      0.250000        0.969524           1.000000  1.969524
# 26      0.250000        0.969524           1.000000  1.969524
# 27      0.250000        0.969524           1.000000  1.969524
# 28      0.333333        0.977143           1.000000  1.977143
# 29      0.333333        0.977143           1.000000  1.977143
# 30      0.333333        1.001905           0.933333  1.935238
# 31      0.333333        1.001905           0.933333  1.935238
# 32      0.166667        1.001905           0.966667  1.968571
# 33      0.166667        1.001905           0.966667  1.968571
# 34      0.166667        1.001905           0.966667  1.968571
# 35      0.166667        1.001905           1.166667  2.168571
# 36           NaN             NaN                NaN       NaN
# 37      0.250000        0.969524           1.000000  1.969524
#
# [38 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['check', 'name', 'variant', 'value', 'maximum', 'unit', 'category',
#        'subcategory', 'note', 'full_name', 'category_count',
#        'subcategory_count', 'full_name_count', 'days', 'category_count%',
#        'subcategory_count%', 'full_name_count%', 'goal', 'category_total',
#        'category%', 'subcategory_total', 'subcategory%', 'category_score',
#        'subcategory_score', 'score', 'day_score'],
#       dtype='object')

# %%
df[["full_name", "goal", 'category_count',
       'subcategory_count', 'full_name_count', "score"]]
# Out:
#                   full_name  goal  category_count  subcategory_count  \
# 0         Lat pulldown wide   2.0             7.0                2.0
# 1        Lat pulldown close   2.0             7.0                2.0
# 2               Rowing pole   1.0             7.0                2.0
# 3            Rowing machine   1.0             7.0                2.0
# 4       Reverse fly machine   2.0             7.0                2.0
# 5        Single row machine   2.0             7.0                2.0
# 6         Back raises plate   1.0             7.0                1.0
# 7          Back raises pole   1.0             7.0                1.0
# 8            Curls dumbells   3.0             2.0                0.0
# 9              Curls hammer   3.0             2.0                0.0
# 10               Curls pole   3.0             2.0                0.0
# 11            Curls machine   3.0             2.0                0.0
# 12              Curls cable   3.0             2.0                0.0
# 13              Curls cable   3.0             2.0                0.0
# 14      Triceps press cable   2.0             2.0                2.0
# 15      Triceps press cable   2.0             2.0                2.0
# 16   Triceps press overhead   2.0             2.0                2.0
# 17        Treadmill running   1.0             0.0                0.0
# 18     Bench press vertical   1.0             4.0                1.0
# 19      Bench press incline   1.0             4.0                1.0
# 20      Bench press incline   1.0             4.0                1.0
# 21      Bench press incline   1.0             4.0                1.0
# 22      Military press pole   1.0             3.0                1.0
# 23  Military press dumbells   1.0             3.0                1.0
# 24             Dips machine   1.0             4.0                1.0
# 25     Bench press negative   1.0             4.0                1.0
# 26              Fly machine   1.0             4.0                1.0
# 27             Fly dumbells   1.0             4.0                1.0
# 28       Side lifting cable   1.0             3.0                1.0
# 29      Front lifting cable   1.0             3.0                1.0
# 30              Squads free   2.0             5.0                2.0
# 31        Leg press machine   2.0             5.0                2.0
# 32       Quadriceps machine   1.0             5.0                1.0
# 33       Hamstrings machine   1.0             5.0                1.0
# 34          Calves standing   1.0             5.0                1.0
# 35          Abdominals free   1.0             5.0                0.0
# 36         Shruggs dumbells   NaN             3.0                0.0
# 37      Bench press pushups   1.0             4.0                1.0
#
#     full_name_count     score
# 0               1.0  1.954286
# 1               1.0  1.954286
# 2               1.0  1.787619
# 3               1.0  1.787619
# 4               1.0  1.954286
# 5               1.0  1.954286
# 6               1.0  1.930476
# 7               0.0  1.930476
# 8               0.0  2.704762
# 9               0.0  2.704762
# 10              0.0  2.704762
# 11              0.0  2.704762
# 12              0.0  2.704762
# 13              0.0  2.704762
# 14              1.0  1.504762
# 15              1.0  1.504762
# 16              1.0  1.504762
# 17              0.0  3.040000
# 18              1.0  1.969524
# 19              1.0  1.969524
# 20              1.0  1.969524
# 21              1.0  1.969524
# 22              1.0  1.977143
# 23              0.0  1.977143
# 24              1.0  1.969524
# 25              0.0  1.969524
# 26              1.0  1.969524
# 27              0.0  1.969524
# 28              1.0  1.977143
# 29              1.0  1.977143
# 30              1.0  1.935238
# 31              1.0  1.935238
# 32              1.0  1.968571
# 33              1.0  1.968571
# 34              1.0  1.968571
# 35              0.0  2.168571
# 36              0.0       NaN
# 37              0.0  1.969524

# %%
import numpy as np

# %%
df["day_score"] = df["days"].fillna(np.inf) * df.score
df.day_score
# Out:
# 0     58.628571
# 1     58.628571
# 2     53.628571
# 3     53.628571
# 4     58.628571
# 5     58.628571
# 6     59.844762
# 7           inf
# 8           inf
# 9           inf
# 10          inf
# 11          inf
# 12          inf
# 13          inf
# 14    28.590476
# 15    28.590476
# 16    28.590476
# 17          inf
# 18    37.420952
# 19    37.420952
# 20    37.420952
# 21    37.420952
# 22    37.565714
# 23          inf
# 24    37.420952
# 25          inf
# 26    37.420952
# 27          inf
# 28    37.565714
# 29    37.565714
# 30    59.992381
# 31    59.992381
# 32    61.025714
# 33    61.025714
# 34    61.025714
# 35          inf
# 36          NaN
# 37          inf
# Name: day_score, dtype: float64

# %%
df.sort_values(["day_score", "category", "subcategory", "name", "variant"], ascending=False)
# Out:
#    check            name   variant value maximum unit   category subcategory  \
# 23        Military press  dumbells    16           kg  shoulders       upper
# 35            Abdominals      free    15                    legs  abdominals
# 25           Bench press  negative    30           kg      chest       lower
# 27                   Fly  dumbells    12           kg      chest       inner
# 37           Bench press   pushups    15                   chest     central
# 17             Treadmill   running    30          min     cardio      cardio
# 7            Back raises      pole    70           kg       back       lower
# 10                 Curls      pole   7.5           kg       arms      bizeps
# 11                 Curls   machine    30           kg       arms      bizeps
# 9                  Curls    hammer    16           kg       arms      bizeps
# 8                  Curls  dumbells    16           kg       arms      bizeps
# 12                 Curls     cable    30           kg       arms      bizeps
# 13                 Curls     cable    30           kg       arms      bizeps
# 32            Quadriceps   machine    65           kg       legs  quadriceps
# 33            Hamstrings   machine    55           kg       legs  hamstrings
# 34                Calves  standing   100           kg       legs      calves
# 30                Squads      free    60           kg       legs        full
# 31             Leg press   machine   160           kg       legs        full
# 6            Back raises     plate    15           kg       back       lower
# 0           Lat pulldown      wide    55           kg       back       outer
# 1           Lat pulldown     close    55           kg       back       outer
# 5             Single row   machine    35           kg       back       inner
# 4            Reverse fly   machine    35           kg       back       inner
# 2                 Rowing      pole    40           kg       back       upper
# 3                 Rowing   machine    50           kg       back       upper
# 22        Military press      pole    40           kg  shoulders       upper
# 28          Side lifting     cable  12.5           kg  shoulders        side
# 29         Front lifting     cable    10           kg  shoulders       front
# 19           Bench press   incline    18                   chest       upper
# 20           Bench press   incline                         chest       upper
# 21           Bench press   incline                         chest       upper
# 24                  Dips   machine    20           kg      chest       lower
# 26                   Fly   machine    55           kg      chest       inner
# 18           Bench press  vertical    60           kg      chest     central
# 16         Triceps press  overhead    45           kg       arms     triceps
# 14         Triceps press     cable    45           kg       arms     triceps
# 15         Triceps press     cable    45           kg       arms     triceps
# 36               Shruggs  dumbells    30           kg  shoulders        neck
#
#         note                full_name  ...  full_name_count%  goal  \
# 23            Military press dumbells  ...               0.0   1.0
# 35                    Abdominals free  ...               0.0   1.0
# 25   machine     Bench press negative  ...               0.0   1.0
# 27                       Fly dumbells  ...               0.0   1.0
# 37                Bench press pushups  ...               0.0   1.0
# 17   machine        Treadmill running  ...               0.0   1.0
# 7                    Back raises pole  ...               0.0   1.0
# 10  preacher               Curls pole  ...               0.0   3.0
# 11  preacher            Curls machine  ...               0.0   3.0
# 9   dumbells             Curls hammer  ...               0.0   3.0
# 8                      Curls dumbells  ...               0.0   3.0
# 12  preacher              Curls cable  ...               0.0   3.0
# 13    normal              Curls cable  ...               0.0   3.0
# 32                 Quadriceps machine  ...               1.0   1.0
# 33                 Hamstrings machine  ...               1.0   1.0
# 34                    Calves standing  ...               1.0   1.0
# 30                        Squads free  ...               0.5   2.0
# 31                  Leg press machine  ...               0.5   2.0
# 6                   Back raises plate  ...               1.0   1.0
# 0    machine        Lat pulldown wide  ...               0.5   2.0
# 1    machine       Lat pulldown close  ...               0.5   2.0
# 5                  Single row machine  ...               0.5   2.0
# 4                 Reverse fly machine  ...               0.5   2.0
# 2                         Rowing pole  ...               0.5   1.0
# 3                      Rowing machine  ...               0.5   1.0
# 22                Military press pole  ...               1.0   1.0
# 28                 Side lifting cable  ...               1.0   1.0
# 29                Front lifting cable  ...               1.0   1.0
# 19  dumbells      Bench press incline  ...               1.0   1.0
# 20      pole      Bench press incline  ...               1.0   1.0
# 21   machine      Bench press incline  ...               1.0   1.0
# 24                       Dips machine  ...               1.0   1.0
# 26                        Fly machine  ...               1.0   1.0
# 18               Bench press vertical  ...               1.0   1.0
# 16             Triceps press overhead  ...               0.5   2.0
# 14      rope      Triceps press cable  ...               0.5   2.0
# 15      pole      Triceps press cable  ...               0.5   2.0
# 36                   Shruggs dumbells  ...               0.0   NaN
#
#     category_total  category%  subcategory_total  subcategory%  \
# 23             3.0       0.12                1.0      0.333333
# 35             6.0       0.24                1.0      0.166667
# 25             4.0       0.16                1.0      0.250000
# 27             4.0       0.16                1.0      0.250000
# 37             4.0       0.16                1.0      0.250000
# 17             1.0       0.04                1.0      1.000000
# 7              6.0       0.24                1.0      0.166667
# 10             5.0       0.20                3.0      0.600000
# 11             5.0       0.20                3.0      0.600000
# 9              5.0       0.20                3.0      0.600000
# 8              5.0       0.20                3.0      0.600000
# 12             5.0       0.20                3.0      0.600000
# 13             5.0       0.20                3.0      0.600000
# 32             6.0       0.24                1.0      0.166667
# 33             6.0       0.24                1.0      0.166667
# 34             6.0       0.24                1.0      0.166667
# 30             6.0       0.24                2.0      0.333333
# 31             6.0       0.24                2.0      0.333333
# 6              6.0       0.24                1.0      0.166667
# 0              6.0       0.24                2.0      0.333333
# 1              6.0       0.24                2.0      0.333333
# 5              6.0       0.24                2.0      0.333333
# 4              6.0       0.24                2.0      0.333333
# 2              6.0       0.24                1.0      0.166667
# 3              6.0       0.24                1.0      0.166667
# 22             3.0       0.12                1.0      0.333333
# 28             3.0       0.12                1.0      0.333333
# 29             3.0       0.12                1.0      0.333333
# 19             4.0       0.16                1.0      0.250000
# 20             4.0       0.16                1.0      0.250000
# 21             4.0       0.16                1.0      0.250000
# 24             4.0       0.16                1.0      0.250000
# 26             4.0       0.16                1.0      0.250000
# 18             4.0       0.16                1.0      0.250000
# 16             5.0       0.20                2.0      0.400000
# 14             5.0       0.20                2.0      0.400000
# 15             5.0       0.20                2.0      0.400000
# 36             NaN        NaN                NaN           NaN
#
#     category_score  subcategory_score     score  day_score
# 23        0.977143           1.000000  1.977143        inf
# 35        1.001905           1.166667  2.168571        inf
# 25        0.969524           1.000000  1.969524        inf
# 27        0.969524           1.000000  1.969524        inf
# 37        0.969524           1.000000  1.969524        inf
# 17        1.040000           2.000000  3.040000        inf
# 7         0.906667           1.023810  1.930476        inf
# 10        1.104762           1.600000  2.704762        inf
# 11        1.104762           1.600000  2.704762        inf
# 9         1.104762           1.600000  2.704762        inf
# 8         1.104762           1.600000  2.704762        inf
# 12        1.104762           1.600000  2.704762        inf
# 13        1.104762           1.600000  2.704762        inf
# 32        1.001905           0.966667  1.968571  61.025714
# 33        1.001905           0.966667  1.968571  61.025714
# 34        1.001905           0.966667  1.968571  61.025714
# 30        1.001905           0.933333  1.935238  59.992381
# 31        1.001905           0.933333  1.935238  59.992381
# 6         0.906667           1.023810  1.930476  59.844762
# 0         0.906667           1.047619  1.954286  58.628571
# 1         0.906667           1.047619  1.954286  58.628571
# 5         0.906667           1.047619  1.954286  58.628571
# 4         0.906667           1.047619  1.954286  58.628571
# 2         0.906667           0.880952  1.787619  53.628571
# 3         0.906667           0.880952  1.787619  53.628571
# 22        0.977143           1.000000  1.977143  37.565714
# 28        0.977143           1.000000  1.977143  37.565714
# 29        0.977143           1.000000  1.977143  37.565714
# 19        0.969524           1.000000  1.969524  37.420952
# 20        0.969524           1.000000  1.969524  37.420952
# 21        0.969524           1.000000  1.969524  37.420952
# 24        0.969524           1.000000  1.969524  37.420952
# 26        0.969524           1.000000  1.969524  37.420952
# 18        0.969524           1.000000  1.969524  37.420952
# 16        1.104762           0.400000  1.504762  28.590476
# 14        1.104762           0.400000  1.504762  28.590476
# 15        1.104762           0.400000  1.504762  28.590476
# 36             NaN                NaN       NaN        NaN
#
# [38 rows x 26 columns]

# %%
df.sort_values(["category_score", "subcategory_score", "name", "variant"], ascending=False)
# Out:
#    check            name   variant value maximum unit   category subcategory  \
# 10                 Curls      pole   7.5           kg       arms      bizeps
# 11                 Curls   machine    30           kg       arms      bizeps
# 9                  Curls    hammer    16           kg       arms      bizeps
# 8                  Curls  dumbells    16           kg       arms      bizeps
# 12                 Curls     cable    30           kg       arms      bizeps
# 13                 Curls     cable    30           kg       arms      bizeps
# 16         Triceps press  overhead    45           kg       arms     triceps
# 14         Triceps press     cable    45           kg       arms     triceps
# 15         Triceps press     cable    45           kg       arms     triceps
# 17             Treadmill   running    30          min     cardio      cardio
# 35            Abdominals      free    15                    legs  abdominals
# 32            Quadriceps   machine    65           kg       legs  quadriceps
# 33            Hamstrings   machine    55           kg       legs  hamstrings
# 34                Calves  standing   100           kg       legs      calves
# 30                Squads      free    60           kg       legs        full
# 31             Leg press   machine   160           kg       legs        full
# 28          Side lifting     cable  12.5           kg  shoulders        side
# 22        Military press      pole    40           kg  shoulders       upper
# 23        Military press  dumbells    16           kg  shoulders       upper
# 29         Front lifting     cable    10           kg  shoulders       front
# 26                   Fly   machine    55           kg      chest       inner
# 27                   Fly  dumbells    12           kg      chest       inner
# 24                  Dips   machine    20           kg      chest       lower
# 18           Bench press  vertical    60           kg      chest     central
# 37           Bench press   pushups    15                   chest     central
# 25           Bench press  negative    30           kg      chest       lower
# 19           Bench press   incline    18                   chest       upper
# 20           Bench press   incline                         chest       upper
# 21           Bench press   incline                         chest       upper
# 5             Single row   machine    35           kg       back       inner
# 4            Reverse fly   machine    35           kg       back       inner
# 0           Lat pulldown      wide    55           kg       back       outer
# 1           Lat pulldown     close    55           kg       back       outer
# 7            Back raises      pole    70           kg       back       lower
# 6            Back raises     plate    15           kg       back       lower
# 2                 Rowing      pole    40           kg       back       upper
# 3                 Rowing   machine    50           kg       back       upper
# 36               Shruggs  dumbells    30           kg  shoulders        neck
#
#         note                full_name  ...  full_name_count%  goal  \
# 10  preacher               Curls pole  ...               0.0   3.0
# 11  preacher            Curls machine  ...               0.0   3.0
# 9   dumbells             Curls hammer  ...               0.0   3.0
# 8                      Curls dumbells  ...               0.0   3.0
# 12  preacher              Curls cable  ...               0.0   3.0
# 13    normal              Curls cable  ...               0.0   3.0
# 16             Triceps press overhead  ...               0.5   2.0
# 14      rope      Triceps press cable  ...               0.5   2.0
# 15      pole      Triceps press cable  ...               0.5   2.0
# 17   machine        Treadmill running  ...               0.0   1.0
# 35                    Abdominals free  ...               0.0   1.0
# 32                 Quadriceps machine  ...               1.0   1.0
# 33                 Hamstrings machine  ...               1.0   1.0
# 34                    Calves standing  ...               1.0   1.0
# 30                        Squads free  ...               0.5   2.0
# 31                  Leg press machine  ...               0.5   2.0
# 28                 Side lifting cable  ...               1.0   1.0
# 22                Military press pole  ...               1.0   1.0
# 23            Military press dumbells  ...               0.0   1.0
# 29                Front lifting cable  ...               1.0   1.0
# 26                        Fly machine  ...               1.0   1.0
# 27                       Fly dumbells  ...               0.0   1.0
# 24                       Dips machine  ...               1.0   1.0
# 18               Bench press vertical  ...               1.0   1.0
# 37                Bench press pushups  ...               0.0   1.0
# 25   machine     Bench press negative  ...               0.0   1.0
# 19  dumbells      Bench press incline  ...               1.0   1.0
# 20      pole      Bench press incline  ...               1.0   1.0
# 21   machine      Bench press incline  ...               1.0   1.0
# 5                  Single row machine  ...               0.5   2.0
# 4                 Reverse fly machine  ...               0.5   2.0
# 0    machine        Lat pulldown wide  ...               0.5   2.0
# 1    machine       Lat pulldown close  ...               0.5   2.0
# 7                    Back raises pole  ...               0.0   1.0
# 6                   Back raises plate  ...               1.0   1.0
# 2                         Rowing pole  ...               0.5   1.0
# 3                      Rowing machine  ...               0.5   1.0
# 36                   Shruggs dumbells  ...               0.0   NaN
#
#     category_total  category%  subcategory_total  subcategory%  \
# 10             5.0       0.20                3.0      0.600000
# 11             5.0       0.20                3.0      0.600000
# 9              5.0       0.20                3.0      0.600000
# 8              5.0       0.20                3.0      0.600000
# 12             5.0       0.20                3.0      0.600000
# 13             5.0       0.20                3.0      0.600000
# 16             5.0       0.20                2.0      0.400000
# 14             5.0       0.20                2.0      0.400000
# 15             5.0       0.20                2.0      0.400000
# 17             1.0       0.04                1.0      1.000000
# 35             6.0       0.24                1.0      0.166667
# 32             6.0       0.24                1.0      0.166667
# 33             6.0       0.24                1.0      0.166667
# 34             6.0       0.24                1.0      0.166667
# 30             6.0       0.24                2.0      0.333333
# 31             6.0       0.24                2.0      0.333333
# 28             3.0       0.12                1.0      0.333333
# 22             3.0       0.12                1.0      0.333333
# 23             3.0       0.12                1.0      0.333333
# 29             3.0       0.12                1.0      0.333333
# 26             4.0       0.16                1.0      0.250000
# 27             4.0       0.16                1.0      0.250000
# 24             4.0       0.16                1.0      0.250000
# 18             4.0       0.16                1.0      0.250000
# 37             4.0       0.16                1.0      0.250000
# 25             4.0       0.16                1.0      0.250000
# 19             4.0       0.16                1.0      0.250000
# 20             4.0       0.16                1.0      0.250000
# 21             4.0       0.16                1.0      0.250000
# 5              6.0       0.24                2.0      0.333333
# 4              6.0       0.24                2.0      0.333333
# 0              6.0       0.24                2.0      0.333333
# 1              6.0       0.24                2.0      0.333333
# 7              6.0       0.24                1.0      0.166667
# 6              6.0       0.24                1.0      0.166667
# 2              6.0       0.24                1.0      0.166667
# 3              6.0       0.24                1.0      0.166667
# 36             NaN        NaN                NaN           NaN
#
#     category_score  subcategory_score     score  day_score
# 10        1.104762           1.600000  2.704762        inf
# 11        1.104762           1.600000  2.704762        inf
# 9         1.104762           1.600000  2.704762        inf
# 8         1.104762           1.600000  2.704762        inf
# 12        1.104762           1.600000  2.704762        inf
# 13        1.104762           1.600000  2.704762        inf
# 16        1.104762           0.400000  1.504762  28.590476
# 14        1.104762           0.400000  1.504762  28.590476
# 15        1.104762           0.400000  1.504762  28.590476
# 17        1.040000           2.000000  3.040000        inf
# 35        1.001905           1.166667  2.168571        inf
# 32        1.001905           0.966667  1.968571  61.025714
# 33        1.001905           0.966667  1.968571  61.025714
# 34        1.001905           0.966667  1.968571  61.025714
# 30        1.001905           0.933333  1.935238  59.992381
# 31        1.001905           0.933333  1.935238  59.992381
# 28        0.977143           1.000000  1.977143  37.565714
# 22        0.977143           1.000000  1.977143  37.565714
# 23        0.977143           1.000000  1.977143        inf
# 29        0.977143           1.000000  1.977143  37.565714
# 26        0.969524           1.000000  1.969524  37.420952
# 27        0.969524           1.000000  1.969524        inf
# 24        0.969524           1.000000  1.969524  37.420952
# 18        0.969524           1.000000  1.969524  37.420952
# 37        0.969524           1.000000  1.969524        inf
# 25        0.969524           1.000000  1.969524        inf
# 19        0.969524           1.000000  1.969524  37.420952
# 20        0.969524           1.000000  1.969524  37.420952
# 21        0.969524           1.000000  1.969524  37.420952
# 5         0.906667           1.047619  1.954286  58.628571
# 4         0.906667           1.047619  1.954286  58.628571
# 0         0.906667           1.047619  1.954286  58.628571
# 1         0.906667           1.047619  1.954286  58.628571
# 7         0.906667           1.023810  1.930476        inf
# 6         0.906667           1.023810  1.930476  59.844762
# 2         0.906667           0.880952  1.787619  53.628571
# 3         0.906667           0.880952  1.787619  53.628571
# 36             NaN                NaN       NaN        NaN
#
# [38 rows x 26 columns]

# %%
import pandas as pd
hist1 = pd.read_csv("history.csv", index_col=0)
hist1.head()
# Out:
#                    name  variant  value  maximum unit category subcategory  \
# 2024-06-27  Back raises    plate   15.0      NaN   kg     back       lower
# 2024-06-27       Squads     free   60.0      NaN   kg     legs        full
# 2024-06-27    Leg press  machine  160.0      NaN   kg     legs        full
# 2024-06-27   Quadriceps  machine   65.0      NaN   kg     legs  quadriceps
# 2024-06-27   Hamstrings  machine   55.0      NaN   kg     legs  hamstrings
#
#            note  last  max
# 2024-06-27  NaN   NaN  NaN
# 2024-06-27  NaN   NaN  NaN
# 2024-06-27  NaN   NaN  NaN
# 2024-06-27  NaN   NaN  NaN
# 2024-06-27  NaN   NaN  NaN

# %%
hist1 = hist1.drop("maximum", axis=1)
hist1.to_csv("history.csv")

# %%
hist2 = pd.read_csv("history.csv")
hist2.head()
# Out:
#    Unnamed: 0         name  variant  value unit category subcategory note  \
# 0  2024-06-27  Back raises    plate   15.0   kg     back       lower  NaN
# 1  2024-06-27       Squads     free   60.0   kg     legs        full  NaN
# 2  2024-06-27    Leg press  machine  160.0   kg     legs        full  NaN
# 3  2024-06-27   Quadriceps  machine   65.0   kg     legs  quadriceps  NaN
# 4  2024-06-27   Hamstrings  machine   55.0   kg     legs  hamstrings  NaN
#
#    last  max
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN
# 3   NaN  NaN
# 4   NaN  NaN

# %%
hist2.rename({"Unnamed: 0": "check"}, axis=1)
# Out:
#          check            name   variant  value unit   category subcategory  \
# 0   2024-06-27     Back raises     plate   15.0   kg       back       lower
# 1   2024-06-27          Squads      free   60.0   kg       legs        full
# 2   2024-06-27       Leg press   machine  160.0   kg       legs        full
# 3   2024-06-27      Quadriceps   machine   65.0   kg       legs  quadriceps
# 4   2024-06-27      Hamstrings   machine   55.0   kg       legs  hamstrings
# 5   2024-06-27          Calves  standing  100.0   kg       legs      calves
# 6   2024-06-28    Lat pulldown      wide   55.0   kg       back       outer
# 7   2024-06-28    Lat pulldown     close   55.0   kg       back       outer
# 8   2024-06-28          Rowing      pole   40.0   kg       back       upper
# 9   2024-06-28          Rowing   machine   50.0   kg       back       upper
# 10  2024-06-28     Reverse fly   machine   35.0   kg       back       inner
# 11  2024-06-28      Single row   machine   35.0   kg       back       inner
# 12  2024-07-09   Triceps press     cable   45.0   kg       arms     triceps
# 13  2024-07-09   Triceps press  overhead   45.0   kg       arms     triceps
# 14  2024-07-09     Bench press  vertical   60.0   kg      chest     central
# 15  2024-07-09     Bench press   incline   18.0  NaN      chest       upper
# 16  2024-07-09  Military press      pole   40.0   kg  shoulders       upper
# 17  2024-07-09            Dips   machine   20.0   kg      chest       lower
# 18  2024-07-09             Fly   machine   55.0   kg      chest       inner
# 19  2024-07-09    Side lifting     cable   12.5   kg  shoulders        side
# 20  2024-07-09   Front lifting     cable   10.0   kg  shoulders       front
# 21  2024-07-28    Lat pulldown      wide   50.0   kg       back       outer
#
#         note  last   max
# 0        NaN   NaN   NaN
# 1        NaN   NaN   NaN
# 2        NaN   NaN   NaN
# 3        NaN   NaN   NaN
# 4        NaN   NaN   NaN
# 5        NaN   NaN   NaN
# 6    machine   NaN   NaN
# 7    machine   NaN   NaN
# 8        NaN   NaN   NaN
# 9        NaN   NaN   NaN
# 10       NaN   NaN   NaN
# 11       NaN   NaN   NaN
# 12      rope   NaN   NaN
# 13       NaN   NaN   NaN
# 14       NaN   NaN   NaN
# 15  dumbells   NaN   NaN
# 16       NaN   NaN   NaN
# 17       NaN   NaN   NaN
# 18       NaN   NaN   NaN
# 19       NaN   NaN   NaN
# 20       NaN   NaN   NaN
# 21   machine  55.0  55.0
